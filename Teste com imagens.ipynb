# %% [markdown]
# ## Resultados da IA

# %%
#Instalando o tensorflow
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Importanto bibliotecas utilizadas
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
class_names = ['Maçãs boas', 'Maçãs podres', 'Negativo']

# %%
# Carregando modelo já treinado
model = tf.keras.models.load_model('modeloMaca.h5')

# Mostrando arquitetura do modelo
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  sequential_5 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_7 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_9 (Conv2D)           (None, 180, 180, 16)      448
#
#  max_pooling2d_9 (MaxPooling  (None, 90, 90, 16)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 90, 90, 32)        4640
#
#  max_pooling2d_10 (MaxPoolin  (None, 45, 45, 32)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 45, 45, 64)        18496
#
#  max_pooling2d_11 (MaxPoolin  (None, 22, 22, 64)       0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 30976)             0
#
#  dense_5 (Dense)             (None, 128)               3965056
#
#  dense_6 (Dense)             (None, 3)                 387
#
# ...
# Total params: 3,989,027
# Trainable params: 3,989,027
# Non-trainable params: 0
# ...

# %%
#Ajustando imagem que passa pela IA
img_height = 180
img_width = 180
img = tf.keras.utils.load_img("gatin.jpg"
    , target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

#Passando a imagem pela IA
predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

#Imprime qual classe pertence
print(
    "Essa imagem é um(a) {} com {:.2f} por cento de confiança"
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)

#Imprime imagem
PIL.Image.open(str("gatin.jpg"))
# Out:
# Essa imagem é um(a) Negativo com 81.07 por cento de confiança
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=718x482 at 0x1FE0036F1F0>

# %%
#Ajustando imagem que passa pela IA
img_height = 180
img_width = 180
img = tf.keras.utils.load_img("maçãboa.jpg"
    , target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

#Passando a imagem pela IA
predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

#Imprime qual classe pertence
print(
    "Essa imagem é um(a) {} com {:.2f} por cento de confiança"
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)

#Imprime imagem
PIL.Image.open(str("maçãboa.jpg"))
# Out:
# Essa imagem é um(a) Maçãs boas com 97.39 por cento de confiança
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=168x300 at 0x1FE0036F370>

# %%
#Ajustando imagem que passa pela IA
img_height = 180
img_width = 180
img = tf.keras.utils.load_img("macaruim.jpg"
    , target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

#Passando a imagem pela IA
predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

#Imprime qual classe pertence
print(
    "Essa imagem é um(a) {} com {:.2f} por cento de confiança"
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)

#Imprime imagem
PIL.Image.open(str("macaruim.jpg"))
# Out:
# Essa imagem é um(a) Maçãs podres com 89.56 por cento de confiança
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=233x216 at 0x1FE004C9A90>

# %% [markdown]
# ### Coloque sua imagem
# Nesse parte você pode verificar se ela consegue distinguir usando alguma imagem que você tenha substituindo o nome_da_imagem pelo nome da imagem que quer testar.
# Observação: tirar as três aspas de inicio e final do código e utilizar imagem jpeg (.jpg)

# %%
"""#Ajustando imagem que passa pela IA
img_height = 180
img_width = 180
img = tf.keras.utils.load_img("nome_da_imagem.jpg", target_size=(img_height, img_width))
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

#Passando a imagem pela IA
predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

#Imprime qual classe pertence
print(
    "Essa imagem é um(a) {} com {:.2f} por cento de confiança"
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)

#Imprime imagem
PIL.Image.open(str("nome_da_imagem.jpg"))"""
